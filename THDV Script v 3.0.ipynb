# %%
import pandas as pd
import openpyxl
from openpyxl import load_workbook
import numpy as np
import win32com.client
import os
# VERSION 3.00
import re
#VERSION  3.01
import datetime

""""
- ADDED 'workbook.close()'  AND 'o.Workbooks.Close()' TO MAKE SURE THAT THE MEMORY GETS REUSED 

"""

# VERSION 3.02
"""
- FIXED THE BORDER LINES IN THE EXCEL FILES
- UPDATE ON THE EXCEL TEMPLATE (V2)
"""
# Out:
# '\n- FIXED THE BORDER LINES IN THE EXCEL FILES\n- UPDATE ON THE EXCEL TEMPLATE (V2)\n'

# %%
# DATA SOURCE (WHERE YOU ARE GETTING ALL THE DATA SCORES)

                
xl = pd.ExcelFile("N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\\FY2019 Priority List Workbook Final - FULL.xlsx")
#xl = pd.ExcelFile("N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\\KC_FY2019 Priority List Workbook Final - Full.xlsx")

pd.set_option('display.max_columns', 500)
xl.sheet_names 

df = xl.parse("TH DV Scoring",header=[0,1,2])

# %%
df.head(2)
# Out:
# Source is APR Data filtered to only TH DV Source is APR Data filtered to only TH DV  \
# **Only APR Grant number Needed                       **Only APR Grant number Needed
# Project #                                                               APR Grant #
# CA0341                                                              CA0341L9D001609
# CA0352                                                              CA0352L9D001609
#
# Source is APR Data filtered to only TH DV                            \
# **Only APR Grant number Needed
# Project #                                 Consolidated FileShare ID
# CA0341                                          CA0341       LA_CPA
# CA0352                                             NaN       LA_JCI
#
# Source is APR Data filtered to only TH DV                                           \
# **Only APR Grant number Needed
# Project #                                                                  Grantee
# ...

# %%
#Grantee names (checking similarities)
df['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','Grantee'].value_counts()
# Out:
# Los Angeles Homeless Services Authority    9
# 1736 Family Crisis Center                  1
# Su Casa ~ Ending Domestic Violence         1
# Name: (Source is APR Data filtered to only TH DV, **Only APR Grant number Needed, Grantee), dtype: int64

# %%
def update_range(worksheet, data, cell_range=None, named_range=None):
     """
     Updates an excel worksheet with the given data.
     :param worksheet: an excel worksheet
     :param data: data used to update the worksheet cell range (list, tuple, np.ndarray, pd.Dataframe)
     :param cell_range: a string representing the cell range, e.g. 'AB12:XX23'
     :param named_range: a string representing an excel named range
     """
 
     def clean_data(data):
         if not isinstance(data, (list, tuple, np.ndarray, pd.DataFrame)):
             raise TypeError('Invalid data, data should be an array type iterable.')
 
         if not len(data):
             raise ValueError('You need to provide data to update the cells')
 
         if isinstance(data, pd.DataFrame):
             data = data.values
 
         elif isinstance(data, (list, tuple)):
             data = np.array(data)
 
         return np.hstack(data)
 
     def clean_cells(worksheet, cell_range, named_range):
         # check that we can access a cell range
         if not any((cell_range, named_range) or all((cell_range, named_range))):
             raise ValueError('`cell_range` or `named_range` should be provided.')
 
         # get the cell range
         if cell_range:
             try:
                 cells = np.hstack(worksheet[cell_range])
             except (CellCoordinatesException, AttributeError):
                 raise ValueError('The cell range provided is invalid, cell range must be in the form XX--[:YY--]')
 
         else:
             try:
                 cells = worksheet.get_named_range(named_range)
             except (NamedRangeException, TypeError):
                 raise ValueError('The current worksheet {} does not contain any named range {}.'.format(
                     worksheet.title,
                     named_range))
 
         # checking that we have cells to update, and data
         if not len(cells):
             raise ValueError('You need to provide cells to update.')
 
         return cells
 
     cells = clean_cells(worksheet, cell_range, named_range)
     data = clean_data(data)
 
     # check that the data has the same dimension as cells
     if len(cells) != data.size:
         raise ValueError('Cells({}) should have the same dimension as the data({}).'.format(len(cells), data.size))
 
     for i, cell in enumerate(cells):
         cell.value = data[i]

# %%
for index,row in df.iterrows():

    #newpath = r'C:\Users\felixa\Documents\Felix\test'
    k = row['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','FileShare ID']
    newpath = r'Q:\\'  + str(k) + '\\Continuum of Care NOFA Renewals\\NOFA 2019\\Renewal Evaluations\\Final Score Reports'
    if not os.path.exists(newpath):
            os.makedirs(newpath)

# %%
# EXCEL FILE HAS BEEN UPDATED

# %%
for index,row in df.iterrows():
    
    
    
    k = row['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','APR Grant #']
    GrantN = df[df['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','APR Grant #'].str.contains(k, na = False)]
    
    
    """ ----------- REMOVE THIS IF YOU WISH TO UPDATE THE EXCEL FILES--------
    
    #Adding the Values ----------
    VALUES1  = pd.DataFrame(index=['Exit to Permanent Housing','Exits to Successful Destination', 'Bed/Unit Unitilization',
                                   'Increase Income Overall','Median Length of Stay', 
                                'Commitment to Policy Priorities', 'Spend Down'],
                             
                         columns=['Points Eearned', 'Points Possible'])
    
    VALUES1.iloc[0] = GrantN['Scoring Area 3: Performance','Exits to Permanent Housing (Q29)'][['Points Earned','Points Possible']].values
    VALUES1.iloc[1] = GrantN['Scoring Area 3: Performance','Exits to Successful Destination (Q29)'][['Points Earned','Points Possible']].values
    
    VALUES1.iloc[2] = GrantN['Scoring Area 1: Bed Utilization','SubTotal'][['Points Earned','Points Possible']].values
    
    VALUES1.iloc[3] = GrantN['Scoring Area 3: Performance','Maintain/Increase Income Overall (APR)'][['Points Earned','Points Possible']].values
    VALUES1.iloc[4] = GrantN['Scoring Area 3: Performance','Median Length of Stay Leavers (Q27)'][['Points Earned','Points Possible']].values
    VALUES1.iloc[5] = GrantN['Housing First','SubTotal'][['Points Earned','Points Possible']].values
    VALUES1.iloc[6] = GrantN['Scoring Area 2: Spend-Down','SubTotal'][['Points Earned','Points Possible']].values
    
    
    #VALUES1['APR Result']  = VALUES1['Points Eearned']/(VALUES1['Points Possible'].replace(0,np.nan))
    
    VALUES1['APR Result']  = [GrantN['Scoring Area 3: Performance','Exits to Permanent Housing (Q29)']['Rate'][0],
                             GrantN['Scoring Area 3: Performance','Exits to Successful Destination (Q29)']['Rate'][0],
                             GrantN['Scoring Area 1: Bed Utilization','SubTotal']['Rate'][0],
                             GrantN['Scoring Area 3: Performance','Maintain/Increase Income Overall (APR)']['Rate'][0],
                             GrantN['Scoring Area 3: Performance','Median Length of Stay Leavers (Q27)']['Rate'][0],
                             GrantN['Housing First','Unnamed: 39_level_1']['Response'][0],
                             GrantN['Scoring Area 2: Spend-Down','Spend-Down Rate (Q31a4)']['Rate'][0]]
    
    VALUES1 = VALUES1[['APR Result', 'Points Eearned', 'Points Possible']]
    
    
    #---------------
    
    VALUES2 = pd.DataFrame(index = ['Grant Number (APR #)', 'Grantee Name', \
                               'Operating Agency', 'Project Name', 'Project Type', 'Target Population', 'FileShare ID']
                      , columns=['values'])
    
    VALUES2.iloc[0] = GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['APR Grant #'].values
    #VALUES2.iloc[1] = GrantN['Source is APR Data filtered to only PSH','**Only APR Grant number Needed']['APR Grant #'].str[0:6].values
    VALUES2.iloc[1] = GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['Grantee'].values
    VALUES2.iloc[2] = GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['Agency'].values
    VALUES2.iloc[3] = GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['Project'].values
        # STILL NEEDS TO ADD PROJECT TYPE
    
    VALUES2.iloc[4] = 'TH DV'#THIS COULD BE A PARAMETER! FOR OUR FUTURE FUNCTION  -FOR THIS CASE WE HAVE RRH 
    VALUES2.iloc[5] = GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['Population'].values
    
    VALUES2.iloc[6] = GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['FileShare ID'].values

    VALUES2['empty1'] = np.nan
   
    
    VALUES2['empty2'] = np.nan
    #VALUES2['empty3'] = np.nan
    VALUES2 = VALUES2[['empty1','values','empty2']]
    
    VALUES3 = pd.DataFrame(index= ['Score Result'], columns =['Total Points Earned', 'Total Points Possible','Project Final Score'])
    VALUES3.iloc[0] = [VALUES1['Points Eearned'].sum(),VALUES1['Points Possible'].sum() ,VALUES1['Points Eearned'].sum()/VALUES1['Points Possible'].sum() ]
    VALUES3[['Total Points Earned', 'Total Points Possible']]
    
    #------------
    
    #Template
    workbook = load_workbook('N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\Priority Listing Working Documents\Evaluation Reports\Final Score Reports\TH DV\Python\Template - THDV v2.xlsx')
    
    worksheet = workbook.active
    worksheet.title = 'template'
    update_range(workbook.active, VALUES1.values, named_range='VALUES1')
    update_range(workbook.active, VALUES2.values, named_range='VALUES2')
    
    
    #total points earned
    update_range(workbook.active, VALUES3[['Total Points Earned', 'Total Points Possible']].values, named_range='VALUES3')


    #Project Final Score
    update_range(workbook.active, VALUES3['Project Final Score'].values, named_range='VALUES4')

    # create a new excel report
    workbook.save(str(k) + '.xlsx')
    workbook.close() # ADDED
    
    
    
    ----DELETE THIS LINE ONLY IF YOU WITH TO UPDATE THE EXCEL FILE--------  """ 
    #-----------------  Turn these into PDF Files ---------
    
    o = win32com.client.Dispatch("Excel.Application")
    o.Visible = False

    
    
    wb_path =  r'N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\Priority Listing Working Documents\Evaluation Reports\Final Score Reports\TH DV\Python\\' +  str(k)  + '.xlsx'

    wb = o.Workbooks.Open(wb_path)



    ws_index_list = [1] #say you want to print these sheets

    # PATH TO THE FILESHARE ID
    path_to_pdf = 'Q:\\' + GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['FileShare ID'] + '\Continuum of Care NOFA Renewals\\NOFA 2019\\Renewal Evaluations\\Final Score Reports\\' + str(k) + '.pdf'
    print(path_to_pdf)
    
    # PATH TO A MASTER COPY
    #path_to_pdf = r'N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\Priority Listing Working Documents\Evaluation Reports\Final Score Reports\TH DV\PDF\\' +  str(k)  + '.pdf'
    #print(path_to_pdf)
    
    #wb.WorkSheets(ws_index_list).Select()

    wb.ActiveSheet.ExportAsFixedFormat(0, path_to_pdf)
      
    o.Workbooks.Close() # ADDED 
d = datetime.datetime.today()
print("FINAL REPORTS FOR TH DV HAVE BEEN COMPLETED! :). Date and Time :" ,d.strftime("%d-%B-%Y %H:%M:%S") )
# Out:
# CA0341    Q:\LA_CPA\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0352    Q:\LA_JCI\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0419    Q:\LA_FTS\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0457    Q:\LA_LTS\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0479    Q:\LA_AVD\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0515    Q:\LA_HOR\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0489    Q:\LA_SCC\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0363    Q:\LA_CPA\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0372    Q:\LA_JFS\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# CA0370    Q:\LA_JFS\Continuum of Care NOFA Renewals\NOFA...
# Name: FileShare ID, dtype: object
# ...

# %%
# TESTING A NEW FOLDER FILE THAT WILL COPY ALL THE THE PDFS INTO THEIR GRANTEE NAMES
# CREATING FOLDERS BASED ON GRANTEE NAMES
# IMPORTANT : ONLY RUN THESE CELL IF YOU WOULD LIKE TO CREATE FOLDERS inside the PHA filder (WHETHER IS PRELIMINARY OR FINAL)


for index,row in df.iterrows():
    #k = row['Grantee']
    #G = df[df['FileShare ID'].str.contains(k,regex=False)]
    k = row['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','APR Grant #']
    GrantN = df[df['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','APR Grant #'].str.contains(k, na = False)]

    BasePath =  r'N:\\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\Priority Listing Working Documents\Evaluation Reports\Final Score Reports\PHA\\' + GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['Grantee'].to_string(index=False)
    #if not os.path.exists(os.path.join(BasePath,k)):
        #os.makedirs(os.path.join(BasePath,k))
    if not os.path.exists(BasePath):
            os.makedirs(BasePath) 

    del GrantN

# %%
import glob

xlsx_directory = glob.glob(r'N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\Priority Listing Working Documents\Evaluation Reports\Final Score Reports\TH DV\PDF\\*.pdf', recursive=True)
xlsx_directory
m =xlsx_directory[0][-19:-4:]
xlsx_directory[0]
# Out:
# 'N:\\Outcomes\\CoC Performance Evaluation Process\\FY2019 NOFA Performance Evaluation Documents\\Priority Listing Working Documents\\Evaluation Reports\\Final Score Reports\\TH DV\\PDF\\CA0341L9D001609.pdf'

# %%
from shutil import copyfile


for index,row in df.iterrows():
    k =  row['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','APR Grant #']
    if k== m:
        GrantN = df[df['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','APR Grant #'].str.contains(k, na = False)]
        BasePath =  r'N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\Priority Listing Working Documents\Evaluation Reports\Final Score Reports\PHA\\' + GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['Grantee'].to_string(index=False)

        copyfile(xlsx_directory[0], BasePath)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-33-8ae8446b20a5> in <module>
#       8         BasePath =  r'N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\Priority Listing Working Documents\Evaluation Reports\Final Score Reports\PHA\\' + GrantN['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed']['Grantee'].to_string(index=False)
#       9
# ---> 10         copyfile(xlsx_directory[0], BasePath)
#      11
#
# ~\AppData\Local\Continuum\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     119     else:
#     120         with open(src, 'rb') as fsrc:
# --> 121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#     123     return dst
#
# ...

# %%
import win32api
e_msg = win32api.FormatMessage(-2147352567)
print (e_msg.decode('CP1251'))

# %%
all_the_files = os.listdir(r'N:\Outcomes\CoC Performance Evaluation Process\FY2019 NOFA Performance Evaluation Documents\Priority Listing Working Documents\Evaluation Reports\Final Score Reports\TH DV\PDF\\')

for file in all_the_files:
    #print(file[0:15])
    if file[0:15] == df['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','APR Grant #'].tolist()[:]:
        print(True)
    else:
        print(False)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
df['Source is APR Data filtered to only TH DV','**Only APR Grant number Needed','APR Grant #'].tolist()[0]
# Out:
# 'CA0341L9D001609'

# %%
for file in all_the_files:
    print(file[0:15])
# Out:
# CA0341L9D001609
# CA0352L9D001609
# CA0363L9D001609
# CA0372L9D001609
# CA0419L9D001609
# CA0457L9D001609
# CA0479L9D001609
# CA0489L9D001609
# CA0515L9D001609

# %%
VALUES2
# Out:
#                       empty1  empty2  \
# Grant Number (APR #)     NaN     NaN
# Grantee Name             NaN     NaN
# Operating Agency         NaN     NaN
# Project Name             NaN     NaN
# Project Type             NaN     NaN
# Target Population        NaN     NaN
# FileShare ID             NaN     NaN
#
#                                                          values
# Grant Number (APR #)                            CA0372L9D001609
# Grantee Name            Los Angeles Homeless Services Authority
# Operating Agency          Jewish Family Services of Los Angeles
# Project Name             Family Violence Project - Hope Cottage
# Project Type                                              TH DV
# Target Population     Domestic Violence, Families with Children
# FileShare ID                                             LA_JFS

# %%
VALUES2['empty1'] = VALUES2['empty1'].replace(np.nan, '', regex=True)

# %%
# Out:
#                                                          values empty1 empty2
# Grant Number (APR #)                            CA0341L9D001609
# Grantee Name            Los Angeles Homeless Services Authority
# Operating Agency            Center for the Pacific Asian Family
# Project Name                  APWC Transitional Housing Program
# Project Type                                              TH DV
# Target Population     Domestic Violence, Families with Children
# FileShare ID                                             LA_CPA
